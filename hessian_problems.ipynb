# %% [markdown]
# Find critical points, Hessian, classification for the problems below.

# %% [markdown]
# f(x,y) = x^2 + y^2
#
# first and second derivatives
#
# f'(x) = 2x
# f'(y) = 2y
#
# f''(x) = 2
# f''(y) = 2
# f''(xy) = 0
# f''(yx) = 0
#
# Critical Point -
# Gradient (partial derivatives at x, y) = 0
#
# 2x = 0 => x = 0
# 2y = 0 => y = 0
#
# critical point = (0,0)
#
# Hessian = [[2,0],[0,2]]
#
# Classification - D = f''(x) * f''(y) - f''(xy)f''(yx)
# D = 4 & f''(x) = 2
# D > 0 & f''(x) > 0 - local minima

# %% [markdown]
# f(x,y) = x^2 - y^2
#
# first and second derivatives
#
# f'(x) = 2x
# f'(y) = -2y
#
# f''(x) = 2
# f''(y) = -2
# f''(xy) = 0
# f''(yx) = 0
#
# Critical Point -
# Gradient (partial derivatives at x, y) = 0
#
# 2x = 0 => x = 0
# -2y = 0 => y = 0
#
# critical point = (0,0)
#
# Hessian = [[2,0],[0,-2]]
#
# Classification - D = f''(x) * f''(y) - f''(xy)f''(yx)
# D = -4 & f''(x) = 2
# D < 0 & f''(x) > 0 - local maxima

# %% [markdown]
# f(x,y) = x^2 + 4xy + y^2
#
# first and second derivatives
#
# f'(x) = 2x + 4y
# f'(y) = 4x + 2y
#
# f''(x) = 2
# f''(y) = 2
# f''(xy) = 4
# f''(yx) = 4
#
# Critical Point -
# Gradient (partial derivatives at x, y) = 0
#
# 2x + 4y = 0 => x = 0
# 2y + 4x = 0 => y = 0
#
# critical point = (0,0)
#
# Hessian = [[2,4],[4,2]]
#
# Classification - D = f''(x) * f''(y) - f''(xy)f''(yx)
# D = -12 & f''(x) = 2
# D < saddle point

# %% [markdown]
# f(x,y) = x^3 - 3xy^2
#
# first and second derivatives
#
# f'(x) = 3x^2 - 6xy
# f'(y) = -6xy
#
# f''(x) = 6x -6y
# f''(y) = -6x
# f''(xy) = -6x
# f''(yx) = -6y
#
# Critical Point -
# Gradient (partial derivatives at x, y) = 0
#
# 3x^2 - 6xy = 0
# -6xy = 0
#
# critical point = (0,0)
#
# Hessian = [[6x -6y,-6x],[-6y,-6x]]
#
# Classification - D = f''(x) * f''(y) - f''(xy)f''(yx)
#
# Hessian at (0,0)
#
# D = 0 -> indeterminant.
