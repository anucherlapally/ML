# %% [markdown]
# You are given a quadratic form: q(x)=x⊤Ax
#
# Explain in one paragraph:
#
# what information q(x) gives
# what role A plays
# what role x plays
#
# q(x) measures how much curvature the quadratic surface has in the direction of x.
# The matrix A encodes how space is stretched or compressed in different directions, and x selects a direction.
# The result is a scalar measuring the strength of that curvature along x.

# %% [markdown]
# (True / False — justify briefly)
#
# a) If A is symmetric, then x⊤Ax is always real.
# b) If x⊤Ax>0 for all nonzero x, then A is invertible.
# c) A matrix with one negative eigenvalue can still be positive semidefinite.
#
# True
# True, all eigenvalues > 0, no zero eigenvalues, which mean matrix is invertible
# False, a matrix with one negative eigenvalue cannot be positive semidefinite because for that to be true eigenvalue >= 0 with atleast one zero

# %% [markdown]
# Let
# A=[[3,0][0,1]], x=[x y]
#
# Compute x⊤Ax explicitly
# Describe geometrically how curvature differs along x and y
#
# computation - 3x^2 + y^2
# Along x the curvature is scaled by 3 and increases steeply, along y it has flat curvature

# %% [markdown]
# Let
# A=[[2,	1],[1, 2]]
# Write x⊤Ax explicitly
#
# Explain why cross-terms appear
# Without computing eigenvalues, predict whether contours are:
# axis-aligned ellipses
# rotated ellipses
# hyperbolas
#
# xTAx = 2x^2+2xy+2y^2
# Cross-terms appear because the curvature directions are not aligned with the coordinate axes. Motion in x affects y curvature and vice versa.
# not sure

# %% [markdown]
# Suppose v is a unit eigenvector of A with eigenvalue λ.
#
# Compute q(tv)
# What does the sign of λ tell you geometrically?
# Why does the answer not depend on the other eigenvectors?
#
# q(tv) = (tv)T A(tv) = = t^2 vT ((lambda)(V)) = t^2 (lambda) (vTv) = t^2 * (lambda)
# λ>0 → curves upward
# λ<0 → curves downward
# λ=0 → flat direction
# Because when moving purely along one eigenvector, the quadratic form decouples and all other directions contribute zero.

# %% [markdown]
# You are given a Hessian with eigenvalues:
# {4,  1,  0,  −2}
#
# Is the matrix PD, PSD, or indefinite?
# What kind of critical point is this?
# What does the zero eigenvalue imply geometrically?
#
# matrix is indefinite - contains atleast one positive and one negative eigenvalue
# saddle point because of mixed positive and negative curvature
# Zero eigenvalue means a flat direction — movement in that direction does not change the function value (locally).

# %% [markdown]
# Write the second-order Taylor expansion of (x+Δx)
#
# Then answer:
# Which term disappears at a critical point and why?
# Why does the remaining term fully determine local behavior?
#
# f(x + Δx) ~ f(x) + (nabla) x T Δx + 1/2 Δx T H(x) Δx
#
# At critical point nabla x = 0 so the first order terms disappears
# the remaining term fully determines the local behavior because it shows the curvature of the point beneath the smoothness

# %% [markdown]
# Newton’s step is:
# Δx=−H−1∇f
#
# Explain mathematically and geometrically:
# Why small eigenvalues cause instability
# Why adding λI fixes this
#
# small eigenvalues blow up the equation and each step becomes huge, this causes instability in the equation. since H is inverse, small values cause huge steps
# Damping which is adding (lambda I) fixes this because it prevents the overshoot

# %% [markdown]
# Why is it far more likely to encounter a saddle point than a minimum in deep learning?
#
# Your answer must explicitly mention eigenvalues.
#
# In higher dimensions we have a large number of eigenvalues playing a part, a large number of eigenvalues indicate a higher chance of different types of values occurring. So encountering a saddle point is far more likely than encountering a minima

# %% [markdown]
# Consider level sets of a quadratic loss:
# x⊤Ax=c
#
# What shape are these level sets when A is PD?
# How does the ratio of eigenvalues affect gradient descent behavior?
# Why does this explain zig-zagging?
#
# Not sure what level sets are
# not sure which ratio of eigenvalues we're talking about
# not sure what zig-zagging is
