# %% [markdown]
# Without doing row-by-row multiplication:
#
# What happens to a square grid under
#
# A=[[1 1] [0 1]]
#
# Choose the best description:
#
# A) rotation
# B) horizontal shear
# C) reflection
# D) uniform scaling
#
# And explain why from the columns.
#
# I think horizontal shear. Considering columns [1 0] and [1 1] with the basis vectors - e1 and e2 - e1 stays the same and e2 is rotated towards e1, for a square grid - it will become a parallelogram with the vertical sides rotated and the horizontal sides staying the same.

# %% [markdown]
# In ML, why can collapsing many inputs to same representation be dangerous?
#
# This results in loss of information
