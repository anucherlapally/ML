# %% [markdown]
# Suppose a matrix sends:
# e1↦(2,0)
# e2↦(0,1)
#
# Answer in words:
# What happens to the x-direction?
# What happens to the y-direction?
# What happens to a general vector?
#
# x-direction points towards the x-axis and the magnitude of the e1 basis vector is 2
# y-direction points towards the y-axis and the magnitude of the e2 basis vector is 1
# I don't understand what the general vector in this case is.
