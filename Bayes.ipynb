# %% [markdown]
# A disease affects 2% of a population.
#
# A test:
#
# Detects disease 95% of the time.
#
# Has 5% false positive rate.
#
#
# Without calculating yet:
#
# Q1:
#
# Which group is larger?
#
# True positives
#
# False positives
#
# Explain structurally.
#
# Healthy population is larger - 98%
# True positives - Of the population that resulted positive, given they have the disease
# False positives - Of the population that resulted positive, given they don't have the disease

# %% [markdown]
# Now assume 10,000 people.
#
# Compute:
#
# Number of diseased - 2%(10,000) = 200
#
# Number of true positives = (0.02)x(0.95) = 0.019
#
# Number of false positives = (0.98)x(0.05) = 0.049
#
# Total positives = 0.019 + 0.049 = 0.068
#
# P(D∣T) = true positives / total positives = 0.019 / 0.068 = 0.279
#
# Do it step by step.

# %% [markdown]
# Explain in one clean sentence:
#
# Why isn’t P(D∣T)=95%?
#
# The probability of disease given test is positive isn't 95% because the test has a false positive rate of 5% while the occurrence of the disease is 2%. It has a high false positive rate against a rare disease so the test isn't efficient and cannot be 95% accurate.

# %% [markdown]
# Suppose:
# We train a highly flexible model on very small data using MLE.
#
# Q4:
# What happens and why?
#
# MLE will overfit the data because it will only consider the small data on a highly flexible model without any regularization.

# %% [markdown]
# We place a Gaussian prior:
# θ∼N(0,σ^2)
# Q5:
#
# If we reduce σ^2, what happens to:
#
# Regularization strength?
#
# Posterior width (assuming small dataset)?
#
# Explain both clearly.
#
# If we reduce the variance, regularization increases. The data is densely packed in this case and outliers are punished heavily.
#
# For a small data set prior variance matters a lot, so if we reduce the variance then uncertainty decreases posterior width narrows around the true parameter. (I'm a little confused here - I feel that the explanation I wrote is correct but if we go according to the formula - posterior is directly proportional to likelihood x prior - prior has variance in the denominator if variance reduces, wouldn't posterior increase? or does it depend on the likelihood term?)

# %% [markdown]
# Suppose:
#
# Dataset size becomes extremely large.
#
# Q6:
#
# What happens to:
#
# Likelihood shape - sharpens
#
# Posterior width - narrows around the true parameters
#
# Prior influence - becomes negligible
