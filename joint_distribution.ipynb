# %% [markdown]
# Scenario 1
#
# Two features:
# Variance of X₁ = 100
# Variance of X₂ = 1
# Covariance = 0
#
# Questions:
# Shape - Skinny ellipse
# Orientation - along the axes - shallow along the x-axis, steep along the y-axis
# Conditioning - ill-conditioning
# Optimization speed - slow, zig-zag behaviour

# %% [markdown]
# Same variances as above (100 and 1),
# but covariance = 9.
#
# What changes geometrically?
#
# rotation occurs, the axes are no longer on the coordinate system

# %% [markdown]
# You standardize both features (mean 0, variance 1).
#
# What happens to:
# Covariance matrix - Identity Matrix
# Conditioning - Perfect conditioning
# Geometry - Unit circle/ sphere
