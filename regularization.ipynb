# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
X, y = make_classification(
    n_samples=1000,
    n_classes=2,
    n_features=20,
    n_redundant=10,
    n_informative=5,
    n_repeated=0,
    random_state=42
)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(X_train)
x_test_scaled = scaler.transform(X_test)

# %%
model = LogisticRegression()

model.fit(x_train_scaled, y_train)
y_test_pred = model.predict(x_test_scaled)
y_train_pred = model.predict(x_train_scaled)

train_accuracy = accuracy_score(y_train, y_train_pred)
print("Train Accuracy: ", train_accuracy)

test_accuracy = accuracy_score(y_test, y_test_pred)
print("Test Accuracy: ", test_accuracy)
# Out:
# Train Accuracy:  0.825
# Test Accuracy:  0.805

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [[-0.15413038 -0.18018988 -0.08857426  0.19679992  0.01787532 -0.58446124
#   -0.09627477  0.03598926  0.03170702 -0.24258486 -0.3062424   0.41886193
#   -0.52723564  0.23328337 -0.25378281 -0.52967626 -0.19575505  0.22778362
#   -0.21355324  0.06974847]]
# [-0.0588166]

# %%
#L2 Regularization
c_list = [100, 10, 1, 0.1, 0.01]
accuracy_scores_test = []
accuracy_scores_train = []

for c in c_list:
    model_l2 = LogisticRegression(penalty='l2', C=c)
    model_l2.fit(x_train_scaled, y_train)
    y_train_pred = model_l2.predict(x_train_scaled)
    y_test_pred = model_l2.predict(x_test_scaled)
    accuracy_scores_test.append(accuracy_score(y_test, y_test_pred))
    accuracy_scores_train.append(accuracy_score(y_train, y_train_pred))
    print("C value: ", c)
    print(model_l2.coef_)

print("**************")
print("Test Accuracy scores: ", accuracy_scores_test)
print("Train Accuracy scores: ",accuracy_scores_train)
# Out:
# C value:  100
# [[-0.15672085 -0.18106449 -0.08940386  0.19810185  0.01745413 -0.58950209
#   -0.09840338  0.03640171  0.03281874 -0.24560317 -0.30858709  0.42264857
#   -0.53139226  0.23515016 -0.25555856 -0.53411105 -0.19823825  0.22926374
#   -0.21523891  0.07099297]]
# C value:  10
# [[-0.15648077 -0.18098397 -0.08932737  0.19798162  0.01749452 -0.58903677
#   -0.09820548  0.03636401  0.032716   -0.24532419 -0.3083708   0.42229916
#   -0.53100866  0.23497776 -0.25539474 -0.53370177 -0.19800882  0.2291273
#   -0.21508353  0.07087795]]
# C value:  1
# [[-0.15413038 -0.18018988 -0.08857426  0.19679992  0.01787532 -0.58446124
#   -0.09627477  0.03598926  0.03170702 -0.24258486 -0.3062424   0.41886193
#   -0.52723564  0.23328337 -0.25378281 -0.52967626 -0.19575505  0.22778362
#   -0.21355324  0.06974847]]
# C value:  0.1
# [[-0.13455734 -0.1730779  -0.08187665  0.18644458  0.0204226  -0.54493922
#   -0.08042193  0.03272123  0.02318993 -0.21912758 -0.28780929  0.38918467
#   -0.4944676   0.21867649 -0.23953298 -0.49481136 -0.17642339  0.21590598
#   -0.20025809  0.06023854]]
# C value:  0.01
# [[-0.06388274 -0.13717735 -0.05067392  0.13707008  0.0186422  -0.36991478
#   -0.02879122  0.01879005 -0.00947791 -0.11990552 -0.20400178  0.25876189
#   -0.3460809   0.15404623 -0.17128594 -0.33815151 -0.09434103  0.15937139
#   -0.13968464  0.0255878 ]]
# **************
# Test Accuracy scores:  [0.805, 0.805, 0.805, 0.8, 0.81]
# Train Accuracy scores:  [0.825, 0.825, 0.825, 0.82625, 0.83]
# c:\Users\AnudeepthiCherlapall\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\AnudeepthiCherlapall\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\AnudeepthiCherlapall\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\AnudeepthiCherlapall\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\AnudeepthiCherlapall\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(

# %%
#L1 Regularization
c_list = [100, 10, 1, 0.1, 0.01]
accuracy_scores_test = []
accuracy_scores_train = []

for c in c_list:
    model_l1 = LogisticRegression(penalty='l1', C=c, solver='liblinear')
    model_l1.fit(x_train_scaled, y_train)
    y_train_pred = model_l1.predict(x_train_scaled)
    y_test_pred = model_l1.predict(x_test_scaled)
    accuracy_scores_test.append(accuracy_score(y_test, y_test_pred))
    accuracy_scores_train.append(accuracy_score(y_train, y_train_pred))
    print("C value: ", c)
    print(model_l1.coef_)

print("**************")
print("Test Accuracy scores: ", accuracy_scores_test)
print("Train Accuracy scores: ",accuracy_scores_train)
# Out:
# C value:  100
# [[-0.15671783 -0.24935813 -0.02921724  0.          0.01717566 -0.25224217
#   -0.09848219  0.03632857  0.20801135 -0.22310498  0.12812664  0.29016721
#   -0.130592    0.61195751 -0.16404376 -1.6306434   0.          0.48035747
#   -0.05419388  0.07088133]]
# C value:  10
# [[-0.15569287  0.         -0.07037248  0.          0.01640837 -0.47247023
#   -0.09728541  0.03545016  0.         -0.18301207  0.          0.46466401
#   -1.03849466  0.         -0.25760915 -0.8187287  -0.01040138  0.01318368
#    0.          0.0698089 ]]
# C value:  1
# [[-0.1455378   0.         -0.02892253  0.          0.00885543 -0.95596298
#   -0.08559316  0.02682794  0.         -0.06186256  0.          0.41251084
#   -0.43672898  0.         -0.52130388 -0.81776052  0.          0.
#    0.          0.05927995]]
# C value:  0.1
# [[-0.05119352  0.          0.          0.          0.         -0.91468189
#    0.          0.          0.          0.          0.          0.2796513
#   -0.34826908  0.         -0.43526462 -0.70257442  0.          0.
#    0.          0.        ]]
# C value:  0.01
# [[ 0.          0.          0.          0.          0.         -0.22261638
#    0.          0.          0.          0.          0.          0.
#   -0.48132093  0.          0.         -0.18426289  0.          0.
#    0.          0.        ]]
# **************
# Test Accuracy scores:  [0.805, 0.805, 0.8, 0.805, 0.795]
# Train Accuracy scores:  [0.825, 0.825, 0.825, 0.83, 0.81375]
# c:\Users\AnudeepthiCherlapall\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\AnudeepthiCherlapall\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1160: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# c:\Users\AnudeepthiCherlapall\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\AnudeepthiCherlapall\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1160: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# c:\Users\AnudeepthiCherlapall\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\AnudeepthiCherlapall\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1160: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# c:\Users\AnudeepthiCherlapall\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\AnudeepthiCherlapall\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1160: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# c:\Users\AnudeepthiCherlapall\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\AnudeepthiCherlapall\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1160: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
