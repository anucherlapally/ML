# %% [markdown]
# What does it physically mean to “hold y constant” when computing ∂x/∂f?
#
# We're only computing the effects on f with changes in x. y in this derivation is treated as a constant.

# %% [markdown]
# Can two different surfaces have the same partial derivatives at a point?
# If yes, what does that imply geometrically?
#
# Surfaces are functions. So two different functions with the same partial derivatives would need to have same powers for x and y with different constants. Geometrically, it would imply that the surface is the same with a shift in the axes.

# %% [markdown]
# At a point (𝑥0,𝑦0), is it possible that:
# ∂x/∂f=0
# ∂y/∂f != 0
#
# What would that look like geometrically?
#
# Yes, it would be possible for a function that does not have the x term or it's a constant. Geometrically, the function is a curve along the y axis

# %% [markdown]
# Why are partial derivatives insufficient to describe the full local behavior of a surface?
#
# partial derivatives are the components of a vector. They are the slopes of the plane in x and y direction. they do not describe the tilt of the plane.

# %% [markdown]
# Why must the gradient be a vector rather than a scalar?
#
# Gradient describes the how much something is and in what direction it's at. This is not possible for a scalar.

# %% [markdown]
# Explain why the gradient does not depend on the direction you move, but the directional derivative does.
#
# A directional derivative is a unit vector, which means that it has a magnitude of one and a direction. It only talks about the direction. Whereas the gradient is an ordinary vector which has both magnitude and direction.

# %% [markdown]
# What does it mean geometrically if ∇f(x0,y0)=(0,0)?
#
# Give two different possibilities for what the surface might look like.
#
# It means that the components of gradient f are 0. I feel like it should be a point on the origin. Unable to think of examples for the surface.

# %% [markdown]
# Why is the gradient perpendicular to level curves?
#
# Explain without using formulas.
#
# Level curves are horizontal to the surface. The steepest ascent is the angle that's perpendicular to the surface and so gradient is always perpendicular to level curves

# %% [markdown]
# Why must the direction vector be normalized when defining a directional derivative?
#
# What goes wrong if it isn’t?
#
# not sure

# %% [markdown]
# What does the dot product ∇f⋅v^ represent geometrically?
#
# I understand that this is the dot product of a gradient and a unit vector. It represents the direction of the gradient with respect to the unit vector, which gives us the directional derivative.

# %% [markdown]
# Why is the maximum directional derivative equal to ∣∇f∣?
#
# The magnitude of the gradient of f is always greater than or equal to the direction of the gradient with respect to any unit vector locally. So the maximum directional derivative must be the unit vector which is parallel to the gradient.
#
# I still need more clarity on this. I feel like there's some gap still.

# %% [markdown]
# Why does moving perpendicular to the gradient produce zero change in f?
#
# because dot product gives us the alignment of one vector w.r.to the other and the geometrical definition of the dot product comes to - |a||b|cos theta. when the angle between the vectors is 90, cos 90 comes to zero.

# %% [markdown]
# Explain how partial derivatives, gradients, and directional derivatives all arise from the same local linear approximation.
#
# Local linear approximation gives us the coefficient of the linear term. Which is the partial derivatives. Gradient is a vector whose components are partial derivatives. Directional derivatives are defined by how the gradient is aligned to a unit vector.

# %% [markdown]
# Why is the gradient the only object that can consistently describe steepest ascent?
#
# Using directional derivative we can prove that gradient describes steepest ascent. I'm still unsure of the math and the logic behind this.

# %% [markdown]
# If a function is not differentiable at a point, which of the following may still exist — and why?
#
# Partial derivatives
# Directional derivatives
# Gradient
#
# I don't think any of them can exist since they are all derived from the differentiation of a function.
